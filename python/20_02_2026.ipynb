# %%
"""open file create"""
import os
os.getenv("/Users/Administrator/Desktop")
f=open("first1.txt","w")
f.write("hi jaya teddy thugu")
f.write("hi reddy thugu jaaya")
f.close()

# %%
"""sub string in a string"""
f=open("first1.txt","r")
n=f.read()
f1=n[2:7]
n1=f.tell()
print(n1)
print(f1)
f.close()
# Out:
# 39
#  jaya

# %%
"""tell use to know courser index and seek use to change cursor place"""
f=open("first1.txt","r")
n=f.tell()
s=f.seek(9)
n1=f.tell()
s1=f.read()
print(s1)
print(n)
print(n1)
f.close()
# Out:
# eddy thuguhi reddy thugu jaaya
# 0
# 9

# %%
"""read lines more"""
f=open("first1.txt","r")
n=f.readlines()
print(n)
f.close()
# Out:
# ['hi\n', 'hello\n', 'gppd\n']

# %%
"""rename chnage file name to another to"""
import os
os.rename("first1.txt","first.txt")

# %%
f=open("first1.txt","x")
f.close()

# %%
"""delete file ok"""
import os
os.remove("first1.txt")

# %%
"""path file use"""
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\307381'

# %%
"""change pathe file"""
os.chdir("C:\\Users\\Administrator\\Desktop")

# %%
"""check file path"""
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
"""list of directiories"""
import os
os.listdir(os.getcwd())
# Out:
# ['desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'Readme - Shortcut.lnk']

# %%
"""create new directory"""
os.mkdir("mark")

# %%
os.listdir(os.getcwd())
# Out:
# ['desktop.ini',
#  'mark',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'Readme - Shortcut.lnk']

# %%
f=open("mark.txt","w+")
f.write("hello hi all to you")
f.seek(0)
n=f.read()
print(n)
f.close()
# Out:
# hello hi all to you

# %%
import os
os.getenv("C:/Users/Administrator/Desktop/mark/first.txt")

# %%
"""create file in a part in dirictory"""
import os
os.getenv("C:/Users/Administrator")
f=open("C:/Users/Administrator/Desktop/mark/first.txt","w+")
f.write("hello hi all to you")
f.seek(0)
n=f.read()
print(n)
f.close()
# Out:
# hello hi all to you

# %%
f=open("first1.txt","w+")
f.write("hello hi all can you tell")
f.seek(0)
n=f.read()
print(n)
f.close()
# Out:
# hello hi all can you tell

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\307381'

# %%
os.chdir("C:\\Users\\Administrator\\Desktop")

# %%
import os
os.getenv("C:/Users/Administrator/Desktop")
os.mkdir("mark2")

# %%
f=open("C:/Users/Administrator/Desktop/mark2/first3.txtx","w+")
f.close()

# %%
"""Delte non empty in directory"""
import shutil
shutil.rmtree("C:/Users/Administrator/Desktop/mark2")

# %%
f=open("C:/Users/Administrator/Desktop/mark/first.txtx","w+")
f.close()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
import os
os.mkdir("math")

# %%
#module and packages
import math as n
print(n.pi)
# Out:
# 3.141592653589793

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 11, 54, 35, 573339)

# %%
#testing
#unit testing
class Bank:
    avlbal=0
    def __init__(self,name,accno,mob):
        self.name=name
        self.accno=accno
        self.mob=mob
    def deposit(self,amount):
        Bank.avlbal=Bank.avlbal+amount
    def withdrawal(self,amt,acc):
        if acc==self.accno:
            if amt<=Bank.avlbal:                
                 print(f"collect rs{amt} thank you all")
                 Bank.avlbal=Bank.avlbal-amt
            else:
                print("insufficient balance please deposit to your account")
        else:
            print("inccort account number")
div=Bank("ram",12345,987654321)
div.deposit(391)
div.withdrawal(279,12345)
print(Bank.avlbal)
# Out:
# collect rs279 thank you all
# 112
