# %%
"""create directory and write value in to it"""
import os
os.getenv("C:/Users/user/OneDrive/Documents")
#os.mkdir("assign1")
f=open("done.txt","w+")
f.write("done,write,ok")
f.tell()
f.seek(3)
div=f.read()
print(div)
f.close()
# Out:
# e,write,ok

# %%
"""shuttle method get"""
import shutil

# %%
"""remove non empty directoty using importing method"""
shutil.rmtree("/content/assign1")
